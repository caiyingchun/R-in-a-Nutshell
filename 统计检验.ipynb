# %%
library(nutshell)
# Out:
# Warning message:
# "package 'nutshell' was built under R version 3.4.3"Loading required package: nutshell.bbdb
# Warning message:
# "package 'nutshell.bbdb' was built under R version 3.4.3"Loading required package: nutshell.audioscrobbler
# Warning message:
# "package 'nutshell.audioscrobbler' was built under R version 3.4.3"

# %%
data(tires.sus)

# %%
time.to.failure.h <- subset(tires.sus, 
                            Tire_Type=='H'&
                            Speed_At_Failure_km_h==160)$Time_To_Failure

# %%
time.to.failure.h
# Out:
#  [1] 10.00 16.67 13.58 13.53 16.83  7.62  4.25 10.67  4.42  4.25

# %%
mean(time.to.failure.h)
# Out:
# [1] 10.182

# %%
t.test(time.to.failure.h, mu = 9)
# Out:
# 	One Sample t-test
#
# data:  time.to.failure.h
# t = 0.75694, df = 9, p-value = 0.4684
# alternative hypothesis: true mean is not equal to 9
# 95 percent confidence interval:
#   6.649536 13.714464
# sample estimates:
# mean of x
#    10.182

# %%
time.to.failure.e <- subset(tires.sus, 
                            Tire_Type=='E'&
                            Speed_At_Failure_km_h==180
                            )$Time_To_Failure
time.to.failure.d <- subset(tires.sus, 
                            Tire_Type=='D'&
                            Speed_At_Failure_km_h==180
                            )$Time_To_Failure
time.to.failure.b <- subset(tires.sus, 
                            Tire_Type=='B'&
                            Speed_At_Failure_km_h==180
                            )$Time_To_Failure

# %%
t.test(time.to.failure.e, time.to.failure.d)
# Out:
# 	Welch Two Sample t-test
#
# data:  time.to.failure.e and time.to.failure.d
# t = -2.5042, df = 8.961, p-value = 0.03373
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.82222528 -0.04148901
# sample estimates:
# mean of x mean of y
#  4.321000  4.752857

# %%
t.test(time.to.failure.e, time.to.failure.b)
# Out:
# 	Welch Two Sample t-test
#
# data:  time.to.failure.e and time.to.failure.b
# t = -1.4549, df = 16.956, p-value = 0.164
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.5591177  0.1027844
# sample estimates:
# mean of x mean of y
#  4.321000  4.549167

# %%
data(field.goals)

# %%
good <- transform(field.goals[field.goals$play.type=='FG good', 
                             c('yards', 'stadium.type')], 
                 outside=(stadium.type=='Out'))
bad <- transform(field.goals[field.goals$play.type=='FG no', 
                             c('yards', 'stadium.type')], 
                 outside=(stadium.type=='Out'))

# %%
good
# Out:
#     yards stadium.type outside
# 1   20    Out          TRUE
# 2   35    Out          TRUE
# 3   24    Out          TRUE
# 4   30    Out          TRUE
# 5   48    Out          TRUE
# 7   26    Out          TRUE
# 8   33    Out          TRUE
# 9   44    Out          TRUE
# 10  29    Out          TRUE
# 11  24    Out          TRUE
# 12  42    Out          TRUE
# 15  32    Out          TRUE
# 16  23    Out          TRUE
# 17  48    Out          TRUE
# 19  46    Out          TRUE
# 20  41    Out          TRUE
# 21  43    Out          TRUE
# 22  45    Out          TRUE
# 23  32    Out          TRUE
# 25  44    Out          TRUE
# 26  29    Out          TRUE
# 27  40    Out          TRUE
# 28  49    Out          TRUE
# 29  39    Out          TRUE
# 30  31    Out          TRUE
# 31  23    Out          TRUE
# 32  28    Out          TRUE
# 34  26    Out          TRUE
# 35  50    Out          TRUE
# 36  53    Out          TRUE
# ... ...   ...          ...
# 942 21    Out          TRUE
# 943 34    Out          TRUE
# 944 30    Out          TRUE
# 945 39    Out          TRUE
# 946 39    Out          TRUE
# 947 35    Out          TRUE
# 948 24    Out          TRUE
# 949 41    Out          TRUE
# 952 21    Out          TRUE
# 953 32    Out          TRUE
# 954 22    Out          TRUE
# 955 48    Out          TRUE
# 956 40    Out          TRUE
# 959 53    Out          TRUE
# 960 19    Out          TRUE
# 962 24    Out          TRUE
# 963 24    Out          TRUE
# 965 19    Out          TRUE
# 966 38    Out          TRUE
# 969 47    Out          TRUE
# 970 39    Out          TRUE
# 971 25    Out          TRUE
# 972 27    Out          TRUE
# 973 47    Out          TRUE
# 975 45    Out          TRUE
# 976 40    Out          TRUE
# 977 43    Out          TRUE
# 979 34    Out          TRUE
# 981 30    Out          TRUE
# 982 38    Out          TRUE

# %%
bad
# Out:
#     yards stadium.type outside
# 13  43    Out           TRUE
# 14  54    Out           TRUE
# 18  38    Out           TRUE
# 24  53    Out           TRUE
# 33  62    Out           TRUE
# 37  49    In           FALSE
# 38  49    In           FALSE
# 61  55    In           FALSE
# 69  45    Out           TRUE
# 71  47    Out           TRUE
# 79  38    Out           TRUE
# 94  48    Out           TRUE
# 105 31    Out           TRUE
# 107 43    Out           TRUE
# 108 44    Out           TRUE
# 111 28    Out           TRUE
# 117 32    Out           TRUE
# 124 45    Out           TRUE
# 135 33    Out           TRUE
# 138 49    Out           TRUE
# 142 33    Out           TRUE
# 146 42    Out           TRUE
# 149 56    Out           TRUE
# 161 36    Out           TRUE
# 163 43    Out           TRUE
# 170 39    Out           TRUE
# 172 48    Out           TRUE
# 176 32    Out           TRUE
# 182 52    Out           TRUE
# 183 44    Out           TRUE
# ... ...   ...          ...
# 818 54    Out           TRUE
# 819 50    Out           TRUE
# 821 40    Out           TRUE
# 822 29    Out           TRUE
# 830 57    Out           TRUE
# 832 56    Out           TRUE
# 842 39    Out           TRUE
# 848 52    Out           TRUE
# 854 31    Out           TRUE
# 860 51    Out           TRUE
# 866 47    Out           TRUE
# 873 44    In           FALSE
# 879 49    In           FALSE
# 889 45    In           FALSE
# 891 48    In           FALSE
# 903 29    Out           TRUE
# 915 46    Out           TRUE
# 921 27    Out           TRUE
# 930 31    Out           TRUE
# 931 38    Out           TRUE
# 934 52    Out           TRUE
# 950 34    Out           TRUE
# 951 46    Out           TRUE
# 957 38    Out           TRUE
# 958 47    Out           TRUE
# 961 52    Out           TRUE
# 964 46    Out           TRUE
# 967 42    Out           TRUE
# 968 47    Out           TRUE
# 974 45    Out           TRUE

# %%
t.test(yards~outside, data=good)
# Out:
# 	Welch Two Sample t-test
#
# data:  yards by outside
# t = 1.1259, df = 319.43, p-value = 0.261
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6851121  2.5185711
# sample estimates:
# mean in group FALSE  mean in group TRUE
#            35.31707            34.40034

# %%
t.test(yards~outside, data=bad)
# Out:
# 	Welch Two Sample t-test
#
# data:  yards by outside
# t = 1.2016, df = 70.726, p-value = 0.2335
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.097564  4.425985
# sample estimates:
# mean in group FALSE  mean in group TRUE
#            45.18421            43.52000

# %%
?transform

# %%
field.goals
# Out:
#     home.team week qtr away.team offense defense play.type  player
# 1   ARI       14   3   WAS       ARI     WAS     FG good    1-N.Rackers
# 2   ARI        2   4   STL       ARI     STL     FG good    1-N.Rackers
# 3   ARI        7   3   TEN       ARI     TEN     FG good    1-N.Rackers
# 4   ARI       12   2   JAC       JAC     ARI     FG good    10-J.Scobee
# 5   ARI        2   3   STL       ARI     STL     FG good    1-N.Rackers
# 6   ARI        7   4   TEN       TEN     ARI     FG aborted 15-C.Hentrich
# 7   ARI        2   2   STL       ARI     STL     FG good    1-N.Rackers
# 8   ARI        7   2   TEN       ARI     TEN     FG good    1-N.Rackers
# 9   ARI       14   2   WAS       ARI     WAS     FG good    1-N.Rackers
# 10  ARI        2   2   STL       STL     ARI     FG good    14-J.Wilkins
# 11  ARI        4   4   SF        ARI     SF      FG good    1-N.Rackers
# 12  ARI       12   3   JAC       ARI     JAC     FG good    1-N.Rackers
# 13  ARI       12   1   JAC       ARI     JAC     FG no      1-N.Rackers
# 14  ARI       16   2   PHI       ARI     PHI     FG no      1-N.Rackers
# 15  ARI       16   1   PHI       ARI     PHI     FG good    1-N.Rackers
# 16  ARI        4   3   SF        ARI     SF      FG good    1-N.Rackers
# 17  ARI        4   3   SF        ARI     SF      FG good    1-N.Rackers
# 18  ARI       12   3   JAC       JAC     ARI     FG no      10-J.Scobee
# 19  ARI        5   1   CAR       CAR     ARI     FG good    4-J.Kasay
# 20  ARI       14   2   WAS       WAS     ARI     FG good    10-J.Hall
# 21  ARI        4   4   SF        ARI     SF      FG good    1-N.Rackers
# 22  ARI        4   2   SF        ARI     SF      FG good    1-N.Rackers
# 23  ARI       16   1   PHI       ARI     PHI     FG good    1-N.Rackers
# 24  ARI        5   2   CAR       CAR     ARI     FG no      4-J.Kasay
# 25  ARI        9   4   SEA       ARI     SEA     FG good    1-N.Rackers
# 26  ARI        2   1   STL       ARI     STL     FG good    1-N.Rackers
# 27  ARI        4   2   SF        ARI     SF      FG good    1-N.Rackers
# 28  ARI        5   3   CAR       ARI     CAR     FG good    1-N.Rackers
# 29  ARI        5   2   CAR       ARI     CAR     FG good    1-N.Rackers
# 30  ARI        9   2   SEA       ARI     SEA     FG good    1-N.Rackers
# ... ...       ...  ... ...       ...     ...     ...        ...
# 953 TEN        8   3   OAK       OAK     TEN     FG good    11-S.Janikowski
# 954 TEN        8   1   OAK       OAK     TEN     FG good    11-S.Janikowski
# 955 WAS       12   4   SD        SD      WAS     FG good    10-N.Kaeding
# 956 WAS        4   3   SEA       WAS     SEA     FG good    3-N.Novak
# 957 WAS       15   1   DAL       DAL     WAS     FG no      3-B.Cundiff
# 958 WAS        4   4   SEA       SEA     WAS     FG no      3-J.Brown
# 959 WAS        4   1   SEA       SEA     WAS     FG good    3-J.Brown
# 960 WAS       11   4   OAK       OAK     WAS     FG good    11-S.Janikowski
# 961 WAS       12   4   SD        WAS     SD      FG no      10-J.Hall
# 962 WAS       11   2   OAK       WAS     OAK     FG good    10-J.Hall
# 963 WAS        9   2   PHI       WAS     PHI     FG good    10-J.Hall
# 964 WAS       12   3   SD        SD      WAS     FG no      10-N.Kaeding
# 965 WAS        1   3   CHI       WAS     CHI     FG good    10-J.Hall
# 966 WAS       12   1   SD        WAS     SD      FG good    10-J.Hall
# 967 WAS       12   1   SD        SD      WAS     FG no      10-N.Kaeding
# 968 WAS        4   3   SEA       SEA     WAS     FG no      3-J.Brown
# 969 WAS       16   1   NYG       NYG     WAS     FG good    2-J.Feely
# 970 WAS        4   5   SEA       WAS     SEA     FG good    3-N.Novak
# 971 WAS       11   4   OAK       OAK     WAS     FG good    11-S.Janikowski
# 972 WAS        7   3   SF        WAS     SF      FG good    3-N.Novak
# 973 WAS        7   4   SF        SF      WAS     FG good    6-J.Nedney
# 974 WAS       11   2   OAK       OAK     WAS     FG no      11-S.Janikowski
# 975 WAS       11   2   OAK       WAS     OAK     FG good    10-J.Hall
# 976 WAS        1   2   CHI       WAS     CHI     FG good    10-J.Hall
# 977 WAS        1   2   CHI       WAS     CHI     FG good    10-J.Hall
# 978 WAS        4   1   SEA       WAS     SEA     FG blocked 3-N.Novak
# 979 WAS        9   3   PHI       PHI     WAS     FG good    2-D.Akers
# 980 WAS       16   3   NYG       NYG     WAS     FG blocked 2-J.Feely
# 981 WAS       11   1   OAK       OAK     WAS     FG good    11-S.Janikowski
# 982 WAS       16   3   NYG       NYG     WAS     FG good    2-J.Feely
#     yards stadium.type
# 1   20    Out
# 2   35    Out
# 3   24    Out
# 4   30    Out
# 5   48    Out
# 6   33    Out
# 7   26    Out
# 8   33    Out
# 9   44    Out
# 10  29    Out
# 11  24    Out
# 12  42    Out
# 13  43    Out
# 14  54    Out
# 15  32    Out
# 16  23    Out
# 17  48    Out
# 18  38    Out
# 19  46    Out
# 20  41    Out
# 21  43    Out
# 22  45    Out
# 23  32    Out
# 24  53    Out
# 25  44    Out
# 26  29    Out
# 27  40    Out
# 28  49    Out
# 29  39    Out
# 30  31    Out
# ... ...   ...
# 953 32    Out
# 954 22    Out
# 955 48    Out
# 956 40    Out
# 957 38    Out
# 958 47    Out
# 959 53    Out
# 960 19    Out
# 961 52    Out
# 962 24    Out
# 963 24    Out
# 964 46    Out
# 965 19    Out
# 966 38    Out
# 967 42    Out
# 968 47    Out
# 969 47    Out
# 970 39    Out
# 971 25    Out
# 972 27    Out
# 973 47    Out
# 974 45    Out
# 975 45    Out
# 976 40    Out
# 977 43    Out
# 978 39    Out
# 979 34    Out
# 980 29    Out
# 981 30    Out
# 982 38    Out

# %%
field.goals.inout <- transform(field.goals, outside=(stadium.type=='Out'))

# %%
t.test(yards~outside, data=field.goals.inout)
# Out:
# 	Welch Two Sample t-test
#
# data:  yards by outside
# t = 1.5473, df = 401.51, p-value = 0.1226
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3152552  2.6461541
# sample estimates:
# mean in group FALSE  mean in group TRUE
#            37.14625            35.98080

# %%
data(SPECint2006)

# %%
SPECint2006
# Out:
#      Benchmark Hardware.Vendor
# 1    CINT2006  ASUS Computer International
# 2    CINT2006  ASUS Computer International
# 3    CINT2006  ASUS Computer International
# 4    CINT2006  ASUS Computer International
# 5    CINT2006  ASUS Computer International
# 6    CINT2006  ASUSTeK Computer Inc.
# 7    CINT2006  ASUSTeK Computer Inc.
# 8    CINT2006  ASUSTeK Computer Inc.
# 9    CINT2006  ASUSTeK Computer Inc.
# 10   CINT2006  ASUSTeK Computer Inc.
# 11   CINT2006  ASUSTeK Computer Inc.
# 12   CINT2006  ASUSTeK Computer Inc.
# 13   CINT2006  ASUSTeK Computer Inc.
# 14   CINT2006  ASUSTeK Computer Inc.
# 15   CINT2006  ASUSTeK Computer Inc.
# 16   CINT2006  ASUSTeK Computer Inc.
# 17   CINT2006  ASUSTeK Computer Inc.
# 18   CINT2006  ASUSTeK Computer Inc.
# 19   CINT2006  ASUSTeK Computer Inc.
# 20   CINT2006  ASUSTeK Computer Inc.
# 21   CINT2006  ASUSTeK Computer Inc.
# 22   CINT2006  ASUSTeK Computer Inc.
# 23   CINT2006  ASUSTeK Computer Inc.
# 24   CINT2006  ASUSTeK Computer Inc.
# 25   CINT2006  ASUSTeK Computer Inc.
# 26   CINT2006  ASUSTeK Computer Inc.
# 27   CINT2006  Apple Computer, Inc.
# 28   CINT2006  Bull SAS
# 29   CINT2006  Bull SAS
# 30   CINT2006  Bull SAS
# ...  ...       ...
# 1204 CINT2006  Supermicro
# 1205 CINT2006  Supermicro
# 1206 CINT2006  Supermicro
# 1207 CINT2006  Supermicro
# 1208 CINT2006  Supermicro
# 1209 CINT2006  Supermicro
# 1210 CINT2006  Supermicro
# 1211 CINT2006  Supermicro
# 1212 CINT2006  Supermicro
# 1213 CINT2006  Supermicro
# 1214 CINT2006  Supermicro
# 1215 CINT2006  Supermicro
# 1216 CINT2006  Supermicro
# 1217 CINT2006  Supermicro
# 1218 CINT2006  Supermicro
# 1219 CINT2006  Supermicro
# 1220 CINT2006  Supermicro
# 1221 CINT2006  Supermicro
# 1222 CINT2006  Supermicro
# 1223 CINT2006  Supermicro
# 1224 CINT2006  Supermicro
# 1225 CINT2006  Supermicro
# 1226 CINT2006  Supermicro
# 1227 CINT2006  Supermicro
# 1228 CINT2006  Supermicro
# 1229 CINT2006  Supermicro
# 1230 CINT2006  Supermicro
# 1231 CINT2006  Tyan
# 1232 CINT2006  Tyan
# 1233 CINT2006  YOYOtech
#      System
# 1    ASUS P5K3 motherboard (Intel Core 2 Duo E6750)
# 2    ASUS P5K3 motherboard (Intel Core 2 Duo E6850)
# 3    ASUS P5K3 motherboard (Intel Core 2 Quad Q6600)
# 4    Asus G2S (Intel Core 2 Duo T7700)
# 5    Asus G2S (Intel Core 2 Duo X7800)
# 6    ASUS DSEB-DG Server Motherboard (Intel XEON X5482)
# 7    ASUS DSEB-DG server motherboard (Intel Xeon X5492)
# 8    ASUS P6T WS PRO workstation motherboard (Intel Core i7-965 Extreme Edition)
# 9    ASUS P6T6 WS REVOLUTION workstation motherboard (Intel Core i7-965 Extreme Edition)
# 10   ASUS RS500-E6/RS520-E6 (Z8NR-D12) server system (Intel Xeon X5570)
# 11   ASUS RS700-E6 server system (Intel Xeon X5570)
# 12   ASUS RS700D (Z8NH-D12) server system (Intel Xeon X5570)
# 13   ASUS TS500-E6 (Z8NA-D6) server system (Intel Xeon X5570)
# 14   ASUS TS700-E6 (Z8PE-D12X) server system (Intel Xeon W5580)
# 15   ASUS Z8NA-D6 server motherboard (Intel Xeon X5570)
# 16   ASUS Z8PE-D12X server motherboard (Intel Xeon X5570)
# 17   ASUS Z8PE-D18 server motherboard (Intel Xeon X5570)
# 18   Asus P5E3 Premium (Intel Core 2 Extreme QX9770)
# 19   Asus P5E3 Premium (Intel Core 2 Quad Q9450)
# 20   Asus P5E3 Premium (Intel Core 2 Quad Q9550)
# 21   Asus P5E3 Premium (Intel Core 2 Quad Q9650)
# 22   Asus P6T Deluxe (Intel Core i7-920)
# 23   Asus P6T Deluxe (Intel Core i7-940)
# 24   Asus P6T Deluxe (Intel Core i7-950)
# 25   Asus P6T Deluxe (Intel Core i7-965 Extreme Edition)
# 26   Asus P6T Deluxe (Intel Core i7-975)
# 27   iMac 20-inch 2.0GHz Intel Core Duo
# 28   Bull Escala PL160 (4.2 GHz, 1 core)
# 29   Bull Escala PL1650R+ (2200 MHz, 1 CPU)
# 30   Bull Escala PL1660 (3.5 GHz, 1 core)
# ...  ...
# 1204 Motherboard H8QM3-2, AMD Opteron 8439 SE
# 1205 Motherboard H8QM8-2, AMD Opteron 8439 SE
# 1206 Motherboard PDSBA+
# 1207 Motherboard PDSM4+
# 1208 Motherboard PDSMI+
# 1209 Motherboard PDSMU
# 1210 Motherboard X7DA3
# 1211 Motherboard X7DA8
# 1212 Motherboard X7DA8
# 1213 Motherboard X7DB3
# 1214 Motherboard X7DB3
# 1215 Motherboard X7DB3
# 1216 Motherboard X7DBR-8+
# 1217 Motherboard X7DWN+
# 1218 Supermicro X7DB8+ (Intel Xeon processor E5310, 1.60 GHz)
# 1219 Supermicro X7DB8+ (Intel Xeon processor E5320, 1.86 GHz)
# 1220 Supermicro X7DB8+ (Intel Xeon processor E5335, 2.00 GHz)
# 1221 Supermicro X7DB8+ (Intel Xeon processor E5345, 2.33 GHz)
# 1222 Supermicro X7DB8+ (Intel Xeon processor E5405, 2.00 GHz)
# 1223 Supermicro X7DB8+ (Intel Xeon processor E5410, 2.33 GHz)
# 1224 Supermicro X7DB8+ (Intel Xeon processor E5420, 2.50 GHz)
# 1225 Supermicro X7DB8+ (Intel Xeon processor E5430, 2.66 GHz)
# 1226 Supermicro X7DB8+ (Intel Xeon processor E5440, 2.83 GHz)
# 1227 Supermicro X7DB8+ (Intel Xeon processor E5450, 3.00 GHz)
# 1228 Supermicro X7DB8+ (Intel Xeon processor X5355, 2.66 GHz)
# 1229 Supermicro X7DB8+ (Intel Xeon processor X5365, 3.00 GHz)
# 1230 Supermicro X7DB8+ (Intel Xeon processor X5460, 3.16 GHz)
# 1231 Thunder K8QW (S4881) Opteron 890
# 1232 n4250QE (S4985) AMD Opteron 2222 SE
# 1233 Fi7EPOWER MLK1610 (Intel Core i7-965)
#      Num.Cores Num.Chips Num.Cores.Per.Chip Result Baseline Published
# 1    2         1         2                  20.5   18.3     Aug-2007
# 2    2         1         2                  22.6   20.2     Aug-2007
# 3    4         1         4                  18.5   16.5     Aug-2007
# 4    2         1         2                  17.3   15.5     Aug-2007
# 5    2         1         2                  18.3   16.4     Aug-2007
# 6    8         2         4                  28.8   25.3     Sep-2008
# 7    8         2         4                  31.4   27.6     Dec-2008
# 8    4         1         4                  35.2   31.5     Feb-2009
# 9    4         1         4                  35.6   32.1     Mar-2009
# 10   8         2         4                  36.0   32.1     May-2009
# 11   8         2         4                  36.1   32.1     Apr-2009
# 12   8         2         4                  36.1   32.0     May-2009
# 13   8         2         4                  36.0   32.1     Jun-2009
# 14   8         2         4                  37.3   33.2     May-2009
# 15   8         2         4                  36.0   32.0     Apr-2009
# 16   8         2         4                  36.0   32.0     Mar-2009
# 17   8         2         4                  36.1   32.1     May-2009
# 18   4         1         4                  29.7   27.0     Nov-2008
# 19   4         1         4                  25.5   23.2     Nov-2008
# 20   4         1         4                  26.8   24.4     Nov-2008
# 21   4         1         4                  28.1   25.6     Nov-2008
# 22   4         1         4                  28.6   25.7     Nov-2008
# 23   4         1         4                  30.8   27.8     Nov-2008
# 24   4         1         4                  32.1   29.1     Jun-2009
# 25   4         1         4                  33.6   30.2     Nov-2008
# 26   4         1         4                  34.9   31.6     Jun-2009
# 27   2         1         2                  10.1   10.1     Aug-2006
# 28   1         1         1                  16.9   14.5     Apr-2008
# 29   1         1         2                  13.2   10.5     Mar-2007
# 30   1         1         2                  16.2   13.3     Apr-2008
# ...  ...       ...       ...                ...    ...      ...
# 1204 24        4         6                  22.4   18.8     Aug-2009
# 1205 24        4         6                  22.6   19.1     Aug-2009
# 1206  2        1         2                  11.2   10.7     May-2007
# 1207  2        1         2                  11.5   10.9     May-2007
# 1208  4        1         4                  17.6   16.7     Aug-2007
# 1209  2        1         2                  12.0   11.5     Jul-2007
# 1210  4        2         2                  14.5   13.8     Aug-2007
# 1211  8        2         4                  16.2   15.5     Jul-2007
# 1212  8        2         4                  16.2   15.5     Jun-2007
# 1213  4        2         2                  17.4   16.2     Aug-2007
# 1214  8        2         4                  16.4   15.7     Jul-2007
# 1215  8        2         4                  16.4   15.7     Jun-2007
# 1216  4        2         2                  14.8   14.1     Jul-2007
# 1217  8        2         4                  26.7   23.3     Nov-2007
# 1218  8        2         4                  14.7   12.6     Oct-2007
# 1219  8        2         4                  16.2   14.1     Oct-2007
# 1220  8        2         4                  18.1   15.6     Oct-2007
# 1221  8        2         4                  20.3   17.5     Oct-2007
# 1222  8        2         4                  19.1   16.6     Dec-2007
# 1223  8        2         4                  21.6   18.8     Dec-2007
# 1224  8        2         4                  22.8   19.8     Dec-2007
# 1225  8        2         4                  24.0   20.9     Dec-2007
# 1226  8        2         4                  25.2   22.0     Dec-2007
# 1227  8        2         4                  26.4   23.0     Dec-2007
# 1228  8        2         4                  22.4   19.4     Oct-2007
# 1229  8        2         4                  24.5   21.1     Oct-2007
# 1230  8        2         4                  27.5   24.0     Dec-2007
# 1231  2        1         2                  13.9   12.6     May-2007
# 1232  2        1         2                  14.9   13.5     Apr-2007
# 1233  4        1         4                  36.0   32.5     Jan-2009

# %%
t.test(subset(SPECint2006, Num.Chips==1&Num.Cores==2)$Baseline, 
       subset(SPECint2006, Num.Chips==1&Num.Cores==2)$Result, 
       paired=TRUE)
# Out:
# 	Paired t-test
#
# data:  subset(SPECint2006, Num.Chips == 1 & Num.Cores == 2)$Baseline and subset(SPECint2006, Num.Chips == 1 & Num.Cores == 2)$Result
# t = -21.804, df = 111, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.957837 -1.631627
# sample estimates:
# mean of the differences
#               -1.794732

# %%
var.test(yards~outside, data=field.goals.inout)
# Out:
# 	F test to compare two variances
#
# data:  yards by outside
# F = 1.2432, num df = 252, denom df = 728, p-value = 0.03098
# alternative hypothesis: true ratio of variances is not equal to 1
# 95 percent confidence interval:
#  1.019968 1.530612
# sample estimates:
# ratio of variances
#           1.243157

# %%
bartlett.test(yards~outside, data=field.goals.inout)
# Out:
# 	Bartlett test of homogeneity of variances
#
# data:  yards by outside
# Bartlett's K-squared = 4.5808, df = 1, p-value = 0.03233

# %%
data(mort06.smpl)

# %%
tapply(mort06.smpl$age, INDEX = list(mort06.smpl$Cause), FUN = summary)
# Out:
# $Accidents
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.00   31.00   48.00   50.88   73.00  108.00       8
#
# $`Alzheimer's Disease`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   40.00   82.00   87.00   86.07   91.00  109.00
#
# $Cancer
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00   61.00   72.00   70.24   81.00  107.00
#
# $`Chronic respiratory diseases`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.00   70.00   78.00   76.37   84.00  106.00       1
#
# $Diabetes
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.00   63.00   75.00   72.43   83.00  104.00       1
#
# $`Heart Disease`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.00   70.00   81.00   77.66   88.00  112.00       4
#
# $Homicide
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.00   22.00   28.00   32.19   42.00   92.00       2
#
# $`Influenza and pheumonia`
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.00   76.00   84.00   80.16   90.00  108.00       1
#
# $Other
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.00   60.00   78.00   70.44   87.00  110.00      10
#
# $Suicide
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    8.00   32.00   45.00   46.14   57.00   97.00       2

# %%
aov(age~Cause, data=mort06.smpl)
# Out:
# Call:
#    aov(formula = age ~ Cause, data = mort06.smpl)
#
# Terms:
#                    Cause Residuals
# Sum of Squares  15727886  72067515
# Deg. of Freedom        9    243034
#
# Residual standard error: 17.22012
# Estimated effects may be unbalanced
# 29 observations deleted due to missingness

# %%
model.tables(aov(age~Cause, data=mort06.smpl))
# Out:
# Tables of effects
#
#  Cause
#     Accidents Alzheimer's Disease    Cancer Chronic respiratory diseases
#        -21.41               13.77    -2.056                        4.077
# rep  12363.00             7336.00 57162.000                    12386.000
#      Diabetes Heart Disease Homicide Influenza and pheumonia     Other Suicide
#        0.1343         5.371    -40.1                   7.863    -1.855  -26.15
# rep 7271.0000     82593.000   1917.0                5826.000 52956.000 3234.00

# %%
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:0: unexpected end of input
# 1: data(births2006.idx (births2006.smpl)
#    ^
# Traceback:

# %%
pairwise.t.test(tires.sus$Time_To_Failure, tires.sus$Tire_Type)
# Out:
# 	Pairwise comparisons using t tests with pooled SD
#
# data:  tires.sus$Time_To_Failure and tires.sus$Tire_Type
#
#   B       C      D       E       H
# C 0.2219  -      -       -       -
# D 1.0000  0.5650 -       -       -
# E 1.0000  0.0769 1.0000  -       -
# H 2.4e-07 0.0029 2.6e-05 1.9e-08 -
# L 0.1147  1.0000 0.4408  0.0291  0.0019
#
# P value adjustment method: holm

# %%
par(mfcol = c(1, 2), ps=6.5)

# %%
shapiro.test(field.goals$yards)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  field.goals$yards
# W = 0.97275, p-value = 1.309e-12

# %%
ks.test(field.goals$yards, pnorm)
# Out:
# Warning message in ks.test(field.goals$yards, pnorm):
# "ties should not be present for the Kolmogorov-Smirnov test"
# 	One-sample Kolmogorov-Smirnov test
#
# data:  field.goals$yards
# D = 1, p-value < 2.2e-16
# alternative hypothesis: two-sided

# %%
ks.test(jitter(subset(SPECint2006, Num.Chips == 1 & Num.Cores == 2)$Baseline),
       jitter(subset(SPECint2006, Num.Chips==1&Num.Cores==2)$Result))
# Out:
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  jitter(subset(SPECint2006, Num.Chips == 1 & Num.Cores == 2)$Baseline) and jitter(subset(SPECint2006, Num.Chips == 1 & Num.Cores == 2)$Result)
# D = 0.21429, p-value = 0.01168
# alternative hypothesis: two-sided

# %%
cor.test(1:8, c(0, 2, 4, 6, 8, 10, 11, 14))
# Out:
# 	Pearson's product-moment correlation
#
# data:  1:8 and c(0, 2, 4, 6, 8, 10, 11, 14)
# t = 36.148, df = 6, p-value = 2.989e-08
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.9868648 0.9996032
# sample estimates:
#      cor
# 0.997712

# %%
cor.test(1:8, c(5, 3, 8, 1, 7, 0, 0, 3))
# Out:
# 	Pearson's product-moment correlation
#
# data:  1:8 and c(5, 3, 8, 1, 7, 0, 0, 3)
# t = -1.2232, df = 6, p-value = 0.2671
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.8757371  0.3764066
# sample estimates:
#        cor
# -0.4467689

# %%
wilcox.test(time.to.failure.e, time.to.failure.d)
# Out:
# Warning message in wilcox.test.default(time.to.failure.e, time.to.failure.d):
# "cannot compute exact p-value with ties"
# 	Wilcoxon rank sum test with continuity correction
#
# data:  time.to.failure.e and time.to.failure.d
# W = 14.5, p-value = 0.05054
# alternative hypothesis: true location shift is not equal to 0

# %%
wilcox.test(yards~outside, data=good)
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  yards by outside
# W = 62045, p-value = 0.393
# alternative hypothesis: true location shift is not equal to 0

# %%
field.goals.goodbad <- field.goals[field.goals$play.type=='FG good' | 
                                   field.goals$play.type=='FG no',]

# %%
field.goals
# Out:
#     home.team week qtr away.team offense defense play.type  player
# 1   ARI       14   3   WAS       ARI     WAS     FG good    1-N.Rackers
# 2   ARI        2   4   STL       ARI     STL     FG good    1-N.Rackers
# 3   ARI        7   3   TEN       ARI     TEN     FG good    1-N.Rackers
# 4   ARI       12   2   JAC       JAC     ARI     FG good    10-J.Scobee
# 5   ARI        2   3   STL       ARI     STL     FG good    1-N.Rackers
# 6   ARI        7   4   TEN       TEN     ARI     FG aborted 15-C.Hentrich
# 7   ARI        2   2   STL       ARI     STL     FG good    1-N.Rackers
# 8   ARI        7   2   TEN       ARI     TEN     FG good    1-N.Rackers
# 9   ARI       14   2   WAS       ARI     WAS     FG good    1-N.Rackers
# 10  ARI        2   2   STL       STL     ARI     FG good    14-J.Wilkins
# 11  ARI        4   4   SF        ARI     SF      FG good    1-N.Rackers
# 12  ARI       12   3   JAC       ARI     JAC     FG good    1-N.Rackers
# 13  ARI       12   1   JAC       ARI     JAC     FG no      1-N.Rackers
# 14  ARI       16   2   PHI       ARI     PHI     FG no      1-N.Rackers
# 15  ARI       16   1   PHI       ARI     PHI     FG good    1-N.Rackers
# 16  ARI        4   3   SF        ARI     SF      FG good    1-N.Rackers
# 17  ARI        4   3   SF        ARI     SF      FG good    1-N.Rackers
# 18  ARI       12   3   JAC       JAC     ARI     FG no      10-J.Scobee
# 19  ARI        5   1   CAR       CAR     ARI     FG good    4-J.Kasay
# 20  ARI       14   2   WAS       WAS     ARI     FG good    10-J.Hall
# 21  ARI        4   4   SF        ARI     SF      FG good    1-N.Rackers
# 22  ARI        4   2   SF        ARI     SF      FG good    1-N.Rackers
# 23  ARI       16   1   PHI       ARI     PHI     FG good    1-N.Rackers
# 24  ARI        5   2   CAR       CAR     ARI     FG no      4-J.Kasay
# 25  ARI        9   4   SEA       ARI     SEA     FG good    1-N.Rackers
# 26  ARI        2   1   STL       ARI     STL     FG good    1-N.Rackers
# 27  ARI        4   2   SF        ARI     SF      FG good    1-N.Rackers
# 28  ARI        5   3   CAR       ARI     CAR     FG good    1-N.Rackers
# 29  ARI        5   2   CAR       ARI     CAR     FG good    1-N.Rackers
# 30  ARI        9   2   SEA       ARI     SEA     FG good    1-N.Rackers
# ... ...       ...  ... ...       ...     ...     ...        ...
# 953 TEN        8   3   OAK       OAK     TEN     FG good    11-S.Janikowski
# 954 TEN        8   1   OAK       OAK     TEN     FG good    11-S.Janikowski
# 955 WAS       12   4   SD        SD      WAS     FG good    10-N.Kaeding
# 956 WAS        4   3   SEA       WAS     SEA     FG good    3-N.Novak
# 957 WAS       15   1   DAL       DAL     WAS     FG no      3-B.Cundiff
# 958 WAS        4   4   SEA       SEA     WAS     FG no      3-J.Brown
# 959 WAS        4   1   SEA       SEA     WAS     FG good    3-J.Brown
# 960 WAS       11   4   OAK       OAK     WAS     FG good    11-S.Janikowski
# 961 WAS       12   4   SD        WAS     SD      FG no      10-J.Hall
# 962 WAS       11   2   OAK       WAS     OAK     FG good    10-J.Hall
# 963 WAS        9   2   PHI       WAS     PHI     FG good    10-J.Hall
# 964 WAS       12   3   SD        SD      WAS     FG no      10-N.Kaeding
# 965 WAS        1   3   CHI       WAS     CHI     FG good    10-J.Hall
# 966 WAS       12   1   SD        WAS     SD      FG good    10-J.Hall
# 967 WAS       12   1   SD        SD      WAS     FG no      10-N.Kaeding
# 968 WAS        4   3   SEA       SEA     WAS     FG no      3-J.Brown
# 969 WAS       16   1   NYG       NYG     WAS     FG good    2-J.Feely
# 970 WAS        4   5   SEA       WAS     SEA     FG good    3-N.Novak
# 971 WAS       11   4   OAK       OAK     WAS     FG good    11-S.Janikowski
# 972 WAS        7   3   SF        WAS     SF      FG good    3-N.Novak
# 973 WAS        7   4   SF        SF      WAS     FG good    6-J.Nedney
# 974 WAS       11   2   OAK       OAK     WAS     FG no      11-S.Janikowski
# 975 WAS       11   2   OAK       WAS     OAK     FG good    10-J.Hall
# 976 WAS        1   2   CHI       WAS     CHI     FG good    10-J.Hall
# 977 WAS        1   2   CHI       WAS     CHI     FG good    10-J.Hall
# 978 WAS        4   1   SEA       WAS     SEA     FG blocked 3-N.Novak
# 979 WAS        9   3   PHI       PHI     WAS     FG good    2-D.Akers
# 980 WAS       16   3   NYG       NYG     WAS     FG blocked 2-J.Feely
# 981 WAS       11   1   OAK       OAK     WAS     FG good    11-S.Janikowski
# 982 WAS       16   3   NYG       NYG     WAS     FG good    2-J.Feely
#     yards stadium.type
# 1   20    Out
# 2   35    Out
# 3   24    Out
# 4   30    Out
# 5   48    Out
# 6   33    Out
# 7   26    Out
# 8   33    Out
# 9   44    Out
# 10  29    Out
# 11  24    Out
# 12  42    Out
# 13  43    Out
# 14  54    Out
# 15  32    Out
# 16  23    Out
# 17  48    Out
# 18  38    Out
# 19  46    Out
# 20  41    Out
# 21  43    Out
# 22  45    Out
# 23  32    Out
# 24  53    Out
# 25  44    Out
# 26  29    Out
# 27  40    Out
# 28  49    Out
# 29  39    Out
# 30  31    Out
# ... ...   ...
# 953 32    Out
# 954 22    Out
# 955 48    Out
# 956 40    Out
# 957 38    Out
# 958 47    Out
# 959 53    Out
# 960 19    Out
# 961 52    Out
# 962 24    Out
# 963 24    Out
# 964 46    Out
# 965 19    Out
# 966 38    Out
# 967 42    Out
# 968 47    Out
# 969 47    Out
# 970 39    Out
# 971 25    Out
# 972 27    Out
# 973 47    Out
# 974 45    Out
# 975 45    Out
# 976 40    Out
# 977 43    Out
# 978 39    Out
# 979 34    Out
# 980 29    Out
# 981 30    Out
# 982 38    Out

# %%
field.goals.table <- table(field.goals.goodbad$play.type, field.goals.goodbad$stadium.type)

# %%
field.goals.table
# Out:
#
#              Both  In Out
#   FG aborted    0   0   0
#   FG blocked    0   0   0
#   FG good      53 152 582
#   FG no        14  24 125

# %%
field.goals.table.t <- t(field.goals.table[3:4, ])

# %%
field.goals.table.t
# Out:
#
#        FG good FG no
#   Both      53    14
#   In       152    24
#   Out      582   125

# %%
prop.test(field.goals.table.t)
# Out:
# 	3-sample test for equality of proportions without continuity
# 	correction
#
# data:  field.goals.table.t
# X-squared = 2.3298, df = 2, p-value = 0.312
# alternative hypothesis: two.sided
# sample estimates:
#    prop 1    prop 2    prop 3
# 0.7910448 0.8636364 0.8231966

# %%
binom.test(x=110, n = 416, p=0.3, alternative = 'less')
# Out:
# 	Exact binomial test
#
# data:  110 and 416
# number of successes = 110, number of trials = 416, p-value = 0.06174
# alternative hypothesis: true probability of success is less than 0.3
# 95 percent confidence interval:
#  0.0000000 0.3023771
# sample estimates:
# probability of success
#              0.2644231
